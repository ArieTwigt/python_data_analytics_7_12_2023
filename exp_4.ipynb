# %%
# import the required modules
import requests
import pandas as pd
import numpy as np
from dotenv import load_dotenv
import os
import json

# %%
# get the environment variable
load_dotenv()
# Out:
# True

# %%
# specify the city and get the appid
city  = "Amsterdam"
appid = os.environ.get('appid')

# %%
# define the endpoint and get the response
endpoint = f"https://api.openweathermap.org/data/2.5/forecast?q={city}&appid={appid}&units=metric"


response = requests.get(endpoint)

# %%
# respons.json()
weather_dict = json.loads(response.text)
weather_dict
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1702026000,
#    'main': {'temp': 2.74,
#     'feels_like': -0.04,
#     'temp_min': 2.74,
#     'temp_max': 3.11,
#     'pressure': 1004,
#     'sea_level': 1004,
#     'grnd_level': 1005,
#     'humidity': 90,
#     'temp_kf': -0.37},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 75},
#    'wind': {'speed': 2.79, 'deg': 165, 'gust': 6.39},
#    'visibility': 10000,
#    'pop': 0.28,
#    'rain': {'3h': 0.23},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-12-08 09:00:00'},
#   {'dt': 1702036800,
#    'main': {'temp': 3.5,
#     'feels_like': 1.05,
#     'temp_min': 3.5,
#     'temp_max': 5.02,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 1005,
#     'humidity': 92,
#     'temp_kf': -1.52},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 83},
#    'wind': {'speed': 2.58, 'deg': 182, 'gust': 5.99},
#    'visibility': 10000,
#    'pop': 0.16,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-12-08 12:00:00'},
#   {'dt': 1702047600,
#    'main': {'temp': 5.79,
#     'feels_like': 3.45,
#     'temp_min': 5.79,
#     'temp_max': 7.31,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 1006,
#     'humidity': 94,
#     'temp_kf': -1.52},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 86},
#    'wind': {'speed': 3, 'deg': 210, 'gust': 8.02},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-12-08 15:00:00'},
#   {'dt': 1702058400,
#    'main': {'temp': 6.17,
#     'feels_like': 3.6,
#     'temp_min': 6.17,
#     'temp_max': 6.17,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1007,
#     'humidity': 97,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 66},
#    'wind': {'speed': 3.48, 'deg': 206, 'gust': 9.79},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-12-08 18:00:00'},
#   {'dt': 1702069200,
#    'main': {'temp': 7.08,
#     'feels_like': 4.01,
#     'temp_min': 7.08,
#     'temp_max': 7.08,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1008,
#     'humidity': 96,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 70},
#    'wind': {'speed': 4.84, 'deg': 210, 'gust': 12.05},
#    'visibility': 10000,
#    'pop': 0.02,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-12-08 21:00:00'},
#   {'dt': 1702080000,
#    'main': {'temp': 7.45,
#     'feels_like': 4.35,
#     'temp_min': 7.45,
#     'temp_max': 7.45,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1008,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 85},
#    'wind': {'speed': 5.13, 'deg': 208, 'gust': 12.03},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-12-09 00:00:00'},
#   {'dt': 1702090800,
#    'main': {'temp': 6.96,
#     'feels_like': 3.68,
#     'temp_min': 6.96,
#     'temp_max': 6.96,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1008,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.24, 'deg': 200, 'gust': 12.72},
#    'visibility': 10000,
#    'pop': 0.23,
#    'rain': {'3h': 0.13},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-12-09 03:00:00'},
#   {'dt': 1702101600,
#    'main': {'temp': 6.67,
#     'feels_like': 3.18,
#     'temp_min': 6.67,
#     'temp_max': 6.67,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1006,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 5.57, 'deg': 180, 'gust': 12.45},
#    'visibility': 10000,
#    'pop': 0.22,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-12-09 06:00:00'},
#   {'dt': 1702112400,
#    'main': {'temp': 6.06,
#     'feels_like': 2.19,
#     'temp_min': 6.06,
#     'temp_max': 6.06,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 1004,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 93},
#    'wind': {'speed': 6.13, 'deg': 180, 'gust': 14.07},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-12-09 09:00:00'},
#   {'dt': 1702123200,
#    'main': {'temp': 7.11,
#     'feels_like': 3.11,
#     'temp_min': 7.11,
#     'temp_max': 7.11,
#     'pressure': 999,
#     'sea_level': 999,
#     'grnd_level': 998,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 7.37, 'deg': 166, 'gust': 14.21},
#    'visibility': 10000,
#    'pop': 0.86,
#    'rain': {'3h': 1.79},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-12-09 12:00:00'},
#   {'dt': 1702134000,
#    'main': {'temp': 7.46,
#     'feels_like': 3.29,
#     'temp_min': 7.46,
#     'temp_max': 7.46,
#     'pressure': 992,
#     'sea_level': 992,
#     'grnd_level': 991,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 8.29, 'deg': 174, 'gust': 16.73},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 3.56},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-12-09 15:00:00'},
#   {'dt': 1702144800,
#    'main': {'temp': 10.84,
#     'feels_like': 10.28,
#     'temp_min': 10.84,
#     'temp_max': 10.84,
#     'pressure': 992,
#     'sea_level': 992,
#     'grnd_level': 991,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 8.36, 'deg': 259, 'gust': 15.49},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 1.82},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-12-09 18:00:00'},
#   {'dt': 1702155600,
#    'main': {'temp': 9.16,
#     'feels_like': 5.27,
#     'temp_min': 9.16,
#     'temp_max': 9.16,
#     'pressure': 996,
#     'sea_level': 996,
#     'grnd_level': 995,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 9.23, 'deg': 261, 'gust': 15.61},
#    'visibility': 10000,
#    'pop': 0.32,
#    'rain': {'3h': 0.16},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-12-09 21:00:00'},
#   {'dt': 1702166400,
#    'main': {'temp': 8.26,
#     'feels_like': 4.04,
#     'temp_min': 8.26,
#     'temp_max': 8.26,
#     'pressure': 998,
#     'sea_level': 998,
#     'grnd_level': 997,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 94},
#    'wind': {'speed': 9.42, 'deg': 257, 'gust': 15.76},
#    'visibility': 10000,
#    'pop': 0.25,
#    'rain': {'3h': 0.22},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-12-10 00:00:00'},
#   {'dt': 1702177200,
#    'main': {'temp': 6.91,
#     'feels_like': 2.09,
#     'temp_min': 6.91,
#     'temp_max': 6.91,
#     'pressure': 999,
#     'sea_level': 999,
#     'grnd_level': 998,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 10.1, 'deg': 253, 'gust': 18.47},
#    'visibility': 9304,
#    'pop': 1,
#    'rain': {'3h': 1.18},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-12-10 03:00:00'},
#   {'dt': 1702188000,
#    'main': {'temp': 8.48,
#     'feels_like': 3.9,
#     'temp_min': 8.48,
#     'temp_max': 8.48,
#     'pressure': 1001,
#     'sea_level': 1001,
#     'grnd_level': 999,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 11.39, 'deg': 268, 'gust': 19.61},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 2.78},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-12-10 06:00:00'},
#   {'dt': 1702198800,
#    'main': {'temp': 8.27,
#     'feels_like': 3.86,
#     'temp_min': 8.27,
#     'temp_max': 8.27,
#     'pressure': 1004,
#     'sea_level': 1004,
#     'grnd_level': 1003,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 10.25, 'deg': 265, 'gust': 16.26},
#    'visibility': 10000,
#    'pop': 0.5,
#    'rain': {'3h': 0.22},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-12-10 09:00:00'},
#   {'dt': 1702209600,
#    'main': {'temp': 8.64,
#     'feels_like': 4.84,
#     'temp_min': 8.64,
#     'temp_max': 8.64,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 1005,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 8.24, 'deg': 262, 'gust': 13.47},
#    'visibility': 10000,
#    'pop': 0.36,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-12-10 12:00:00'},
#   {'dt': 1702220400,
#    'main': {'temp': 8.44,
#     'feels_like': 5.06,
#     'temp_min': 8.44,
#     'temp_max': 8.44,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1006,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 6.6, 'deg': 247, 'gust': 12.95},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-12-10 15:00:00'},
#   {'dt': 1702231200,
#    'main': {'temp': 7.74,
#     'feels_like': 5.57,
#     'temp_min': 7.74,
#     'temp_max': 7.74,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 1004,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 95},
#    'wind': {'speed': 3.36, 'deg': 230, 'gust': 8.46},
#    'visibility': 10000,
#    'pop': 0.87,
#    'rain': {'3h': 1.69},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-12-10 18:00:00'},
#   {'dt': 1702242000,
#    'main': {'temp': 7.49,
#     'feels_like': 5.06,
#     'temp_min': 7.49,
#     'temp_max': 7.49,
#     'pressure': 1003,
#     'sea_level': 1003,
#     'grnd_level': 1001,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.73, 'deg': 174, 'gust': 9.82},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.88},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-12-10 21:00:00'},
#   {'dt': 1702252800,
#    'main': {'temp': 9.23,
#     'feels_like': 7.09,
#     'temp_min': 9.23,
#     'temp_max': 9.23,
#     'pressure': 1002,
#     'sea_level': 1002,
#     'grnd_level': 1001,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.92, 'deg': 260, 'gust': 9.43},
#    'visibility': 10000,
#    'pop': 0.78,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-12-11 00:00:00'},
#   {'dt': 1702263600,
#    'main': {'temp': 8.59,
#     'feels_like': 6.12,
#     'temp_min': 8.59,
#     'temp_max': 8.59,
#     'pressure': 1004,
#     'sea_level': 1004,
#     'grnd_level': 1003,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 94},
#    'wind': {'speed': 4.31, 'deg': 264, 'gust': 9.24},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-12-11 03:00:00'},
#   {'dt': 1702274400,
#    'main': {'temp': 7.65,
#     'feels_like': 5.54,
#     'temp_min': 7.65,
#     'temp_max': 7.65,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 1004,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 94},
#    'wind': {'speed': 3.24, 'deg': 245, 'gust': 8.14},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-12-11 06:00:00'},
#   {'dt': 1702285200,
#    'main': {'temp': 7.98,
#     'feels_like': 5.9,
#     'temp_min': 7.98,
#     'temp_max': 7.98,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 1005,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 96},
#    'wind': {'speed': 3.3, 'deg': 240, 'gust': 8.69},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-12-11 09:00:00'},
#   {'dt': 1702296000,
#    'main': {'temp': 9.56,
#     'feels_like': 7.27,
#     'temp_min': 9.56,
#     'temp_max': 9.56,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1006,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 95},
#    'wind': {'speed': 4.42, 'deg': 237, 'gust': 9.87},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-12-11 12:00:00'},
#   {'dt': 1702306800,
#    'main': {'temp': 9.11,
#     'feels_like': 6.86,
#     'temp_min': 9.11,
#     'temp_max': 9.11,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1006,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.11, 'deg': 236, 'gust': 10.45},
#    'visibility': 10000,
#    'pop': 0.74,
#    'rain': {'3h': 0.92},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-12-11 15:00:00'},
#   {'dt': 1702317600,
#    'main': {'temp': 9.44,
#     'feels_like': 6.62,
#     'temp_min': 9.44,
#     'temp_max': 9.44,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1007,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.75, 'deg': 242, 'gust': 12.13},
#    'visibility': 10000,
#    'pop': 0.72,
#    'rain': {'3h': 0.51},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-12-11 18:00:00'},
#   {'dt': 1702328400,
#    'main': {'temp': 10.08,
#     'feels_like': 9.42,
#     'temp_min': 10.08,
#     'temp_max': 10.08,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1008,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 5.38, 'deg': 240, 'gust': 11.88},
#    'visibility': 10000,
#    'pop': 0.34,
#    'rain': {'3h': 0.13},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-12-11 21:00:00'},
#   {'dt': 1702339200,
#    'main': {'temp': 9.92,
#     'feels_like': 7.57,
#     'temp_min': 9.92,
#     'temp_max': 9.92,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1008,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 4.78, 'deg': 242, 'gust': 11.44},
#    'visibility': 10000,
#    'pop': 0.22,
#    'rain': {'3h': 0.15},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-12-12 00:00:00'},
#   {'dt': 1702350000,
#    'main': {'temp': 9.43,
#     'feels_like': 7.42,
#     'temp_min': 9.43,
#     'temp_max': 9.43,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1007,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 3.76, 'deg': 224, 'gust': 9.18},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.15},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-12-12 03:00:00'},
#   {'dt': 1702360800,
#    'main': {'temp': 9.02,
#     'feels_like': 7.03,
#     'temp_min': 9.02,
#     'temp_max': 9.02,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1007,
#     'humidity': 96,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 3.54, 'deg': 217, 'gust': 8.26},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-12-12 06:00:00'},
#   {'dt': 1702371600,
#    'main': {'temp': 9.3,
#     'feels_like': 8.17,
#     'temp_min': 9.3,
#     'temp_max': 9.3,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1005,
#     'humidity': 96,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.26, 'deg': 186, 'gust': 5.72},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-12-12 09:00:00'},
#   {'dt': 1702382400,
#    'main': {'temp': 9.82,
#     'feels_like': 8.56,
#     'temp_min': 9.82,
#     'temp_max': 9.82,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 1003,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.57, 'deg': 171, 'gust': 5.77},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.13},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-12-12 12:00:00'},
#   {'dt': 1702393200,
#    'main': {'temp': 9.45,
#     'feels_like': 8.53,
#     'temp_min': 9.45,
#     'temp_max': 9.45,
#     'pressure': 1003,
#     'sea_level': 1003,
#     'grnd_level': 1002,
#     'humidity': 99,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.02, 'deg': 178, 'gust': 4.86},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 1.83},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-12-12 15:00:00'},
#   {'dt': 1702404000,
#    'main': {'temp': 8.8,
#     'feels_like': 7.35,
#     'temp_min': 8.8,
#     'temp_max': 8.8,
#     'pressure': 1002,
#     'sea_level': 1002,
#     'grnd_level': 1001,
#     'humidity': 98,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 2.57, 'deg': 169, 'gust': 5.76},
#    'visibility': 10000,
#    'pop': 0.94,
#    'rain': {'3h': 0.29},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-12-12 18:00:00'},
#   {'dt': 1702414800,
#    'main': {'temp': 9.22,
#     'feels_like': 6.97,
#     'temp_min': 9.22,
#     'temp_max': 9.22,
#     'pressure': 1001,
#     'sea_level': 1001,
#     'grnd_level': 1000,
#     'humidity': 96,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 4.16, 'deg': 219, 'gust': 10.42},
#    'visibility': 8215,
#    'pop': 0.67,
#    'rain': {'3h': 0.82},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-12-12 21:00:00'},
#   {'dt': 1702425600,
#    'main': {'temp': 9.21,
#     'feels_like': 6.85,
#     'temp_min': 9.21,
#     'temp_max': 9.21,
#     'pressure': 1000,
#     'sea_level': 1000,
#     'grnd_level': 998,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.4, 'deg': 201, 'gust': 10.44},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 2.02},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-12-13 00:00:00'},
#   {'dt': 1702436400,
#    'main': {'temp': 8.93,
#     'feels_like': 6.86,
#     'temp_min': 8.93,
#     'temp_max': 8.93,
#     'pressure': 998,
#     'sea_level': 998,
#     'grnd_level': 997,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.66, 'deg': 209, 'gust': 8.63},
#    'visibility': 10000,
#    'pop': 0.7,
#    'rain': {'3h': 0.78},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-12-13 03:00:00'},
#   {'dt': 1702447200,
#    'main': {'temp': 8.45,
#     'feels_like': 6.34,
#     'temp_min': 8.45,
#     'temp_max': 8.45,
#     'pressure': 998,
#     'sea_level': 998,
#     'grnd_level': 997,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.53, 'deg': 203, 'gust': 7.25},
#    'visibility': 10000,
#    'pop': 0.8,
#    'rain': {'3h': 1.32},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-12-13 06:00:00'}],
#  'city': {'id': 2759794,
#   'name': 'Amsterdam',
#   'coord': {'lat': 52.374, 'lon': 4.8897},
#   'country': 'NL',
#   'population': 2122311,
#   'timezone': 3600,
#   'sunrise': 1702021001,
#   'sunset': 1702049276}}

# %%
# show the highest level keys
weather_dict.keys()
# Out:
# dict_keys(['cod', 'message', 'cnt', 'list', 'city'])

# %%
# show the information of the city
weather_dict['city']
# Out:
# {'id': 2759794,
#  'name': 'Amsterdam',
#  'coord': {'lat': 52.374, 'lon': 4.8897},
#  'country': 'NL',
#  'population': 2122311,
#  'timezone': 3600,
#  'sunrise': 1702021001,
#  'sunset': 1702049276}

# %%
# show the list of predictions
weather_dict['list'][0]['main']['temp']
# Out:
# 2.74

# %%
weather_dict['list'][39]['main']['temp']
# Out:
# 8.45

# %%
# collect the data from the weather dict
weather_temp = []
weather_feels_like = []
weather_rain_mm = []
weather_description = []
weather_dt_txt = []
weather_wind_speed = []


# iterate over the predictions in the list
for i, prediction in enumerate(weather_dict['list']):
    weather_temp.append(prediction['main']['temp'])
    weather_feels_like.append(prediction['main']['feels_like'])
    if 'rain' in prediction.keys():
        weather_rain_mm.append(prediction['rain']['3h'])
    else:
        weather_rain_mm.append(0)
    weather_description.append(prediction['weather'][0]['description'])
    weather_dt_txt.append(prediction['dt_txt'])
    weather_wind_speed.append(weather_dict['list'][i]['wind']['speed'])

# %%
weather_wind_speed[:5]
# Out:
# [2.79, 2.58, 3, 3.48, 4.84]

# %%
# list comprehension
freeze_non_freeze = [x for x in weather_temp if x < 5]
freeze_non_freeze
# Out:
# [2.74, 3.5]

# %%
# dict comprehension
{   dt:{"temperature": temp,
        "description": description,
        "feels_like": feels_like,
        "rain": rain,
        "wind_speed": wind_speed
        }
 
    for description, temp, dt, feels_like, rain, wind_speed
    in zip(weather_description, weather_temp, 
           weather_dt_txt, weather_feels_like, weather_rain_mm, weather_wind_speed)
}
# Out:
# {'2023-12-08 09:00:00': {'temperature': 2.74,
#   'description': 'light rain',
#   'feels_like': -0.04,
#   'rain': 0.23,
#   'wind_speed': 2.79},
#  '2023-12-08 12:00:00': {'temperature': 3.5,
#   'description': 'broken clouds',
#   'feels_like': 1.05,
#   'rain': 0,
#   'wind_speed': 2.58},
#  '2023-12-08 15:00:00': {'temperature': 5.79,
#   'description': 'overcast clouds',
#   'feels_like': 3.45,
#   'rain': 0,
#   'wind_speed': 3},
#  '2023-12-08 18:00:00': {'temperature': 6.17,
#   'description': 'broken clouds',
#   'feels_like': 3.6,
#   'rain': 0,
#   'wind_speed': 3.48},
#  '2023-12-08 21:00:00': {'temperature': 7.08,
#   'description': 'broken clouds',
#   'feels_like': 4.01,
#   'rain': 0,
#   'wind_speed': 4.84},
#  '2023-12-09 00:00:00': {'temperature': 7.45,
#   'description': 'overcast clouds',
#   'feels_like': 4.35,
#   'rain': 0,
#   'wind_speed': 5.13},
#  '2023-12-09 03:00:00': {'temperature': 6.96,
#   'description': 'light rain',
#   'feels_like': 3.68,
#   'rain': 0.13,
#   'wind_speed': 5.24},
#  '2023-12-09 06:00:00': {'temperature': 6.67,
#   'description': 'overcast clouds',
#   'feels_like': 3.18,
#   'rain': 0,
#   'wind_speed': 5.57},
#  '2023-12-09 09:00:00': {'temperature': 6.06,
#   'description': 'overcast clouds',
#   'feels_like': 2.19,
#   'rain': 0,
#   'wind_speed': 6.13},
#  '2023-12-09 12:00:00': {'temperature': 7.11,
#   'description': 'light rain',
#   'feels_like': 3.11,
#   'rain': 1.79,
#   'wind_speed': 7.37},
#  '2023-12-09 15:00:00': {'temperature': 7.46,
#   'description': 'moderate rain',
#   'feels_like': 3.29,
#   'rain': 3.56,
#   'wind_speed': 8.29},
#  '2023-12-09 18:00:00': {'temperature': 10.84,
#   'description': 'light rain',
#   'feels_like': 10.28,
#   'rain': 1.82,
#   'wind_speed': 8.36},
#  '2023-12-09 21:00:00': {'temperature': 9.16,
#   'description': 'light rain',
#   'feels_like': 5.27,
#   'rain': 0.16,
#   'wind_speed': 9.23},
#  '2023-12-10 00:00:00': {'temperature': 8.26,
#   'description': 'light rain',
#   'feels_like': 4.04,
#   'rain': 0.22,
#   'wind_speed': 9.42},
#  '2023-12-10 03:00:00': {'temperature': 6.91,
#   'description': 'light rain',
#   'feels_like': 2.09,
#   'rain': 1.18,
#   'wind_speed': 10.1},
#  '2023-12-10 06:00:00': {'temperature': 8.48,
#   'description': 'light rain',
#   'feels_like': 3.9,
#   'rain': 2.78,
#   'wind_speed': 11.39},
#  '2023-12-10 09:00:00': {'temperature': 8.27,
#   'description': 'light rain',
#   'feels_like': 3.86,
#   'rain': 0.22,
#   'wind_speed': 10.25},
#  '2023-12-10 12:00:00': {'temperature': 8.64,
#   'description': 'overcast clouds',
#   'feels_like': 4.84,
#   'rain': 0,
#   'wind_speed': 8.24},
#  '2023-12-10 15:00:00': {'temperature': 8.44,
#   'description': 'overcast clouds',
#   'feels_like': 5.06,
#   'rain': 0,
#   'wind_speed': 6.6},
#  '2023-12-10 18:00:00': {'temperature': 7.74,
#   'description': 'light rain',
#   'feels_like': 5.57,
#   'rain': 1.69,
#   'wind_speed': 3.36},
#  '2023-12-10 21:00:00': {'temperature': 7.49,
#   'description': 'light rain',
#   'feels_like': 5.06,
#   'rain': 0.88,
#   'wind_speed': 3.73},
#  '2023-12-11 00:00:00': {'temperature': 9.23,
#   'description': 'overcast clouds',
#   'feels_like': 7.09,
#   'rain': 0,
#   'wind_speed': 3.92},
#  '2023-12-11 03:00:00': {'temperature': 8.59,
#   'description': 'overcast clouds',
#   'feels_like': 6.12,
#   'rain': 0,
#   'wind_speed': 4.31},
#  '2023-12-11 06:00:00': {'temperature': 7.65,
#   'description': 'overcast clouds',
#   'feels_like': 5.54,
#   'rain': 0,
#   'wind_speed': 3.24},
#  '2023-12-11 09:00:00': {'temperature': 7.98,
#   'description': 'overcast clouds',
#   'feels_like': 5.9,
#   'rain': 0,
#   'wind_speed': 3.3},
#  '2023-12-11 12:00:00': {'temperature': 9.56,
#   'description': 'overcast clouds',
#   'feels_like': 7.27,
#   'rain': 0,
#   'wind_speed': 4.42},
#  '2023-12-11 15:00:00': {'temperature': 9.11,
#   'description': 'light rain',
#   'feels_like': 6.86,
#   'rain': 0.92,
#   'wind_speed': 4.11},
#  '2023-12-11 18:00:00': {'temperature': 9.44,
#   'description': 'light rain',
#   'feels_like': 6.62,
#   'rain': 0.51,
#   'wind_speed': 5.75},
#  '2023-12-11 21:00:00': {'temperature': 10.08,
#   'description': 'light rain',
#   'feels_like': 9.42,
#   'rain': 0.13,
#   'wind_speed': 5.38},
#  '2023-12-12 00:00:00': {'temperature': 9.92,
#   'description': 'light rain',
#   'feels_like': 7.57,
#   'rain': 0.15,
#   'wind_speed': 4.78},
#  '2023-12-12 03:00:00': {'temperature': 9.43,
#   'description': 'light rain',
#   'feels_like': 7.42,
#   'rain': 0.15,
#   'wind_speed': 3.76},
#  '2023-12-12 06:00:00': {'temperature': 9.02,
#   'description': 'overcast clouds',
#   'feels_like': 7.03,
#   'rain': 0,
#   'wind_speed': 3.54},
#  '2023-12-12 09:00:00': {'temperature': 9.3,
#   'description': 'overcast clouds',
#   'feels_like': 8.17,
#   'rain': 0,
#   'wind_speed': 2.26},
#  '2023-12-12 12:00:00': {'temperature': 9.82,
#   'description': 'light rain',
#   'feels_like': 8.56,
#   'rain': 0.13,
#   'wind_speed': 2.57},
#  '2023-12-12 15:00:00': {'temperature': 9.45,
#   'description': 'light rain',
#   'feels_like': 8.53,
#   'rain': 1.83,
#   'wind_speed': 2.02},
#  '2023-12-12 18:00:00': {'temperature': 8.8,
#   'description': 'light rain',
#   'feels_like': 7.35,
#   'rain': 0.29,
#   'wind_speed': 2.57},
#  '2023-12-12 21:00:00': {'temperature': 9.22,
#   'description': 'light rain',
#   'feels_like': 6.97,
#   'rain': 0.82,
#   'wind_speed': 4.16},
#  '2023-12-13 00:00:00': {'temperature': 9.21,
#   'description': 'light rain',
#   'feels_like': 6.85,
#   'rain': 2.02,
#   'wind_speed': 4.4},
#  '2023-12-13 03:00:00': {'temperature': 8.93,
#   'description': 'light rain',
#   'feels_like': 6.86,
#   'rain': 0.78,
#   'wind_speed': 3.66},
#  '2023-12-13 06:00:00': {'temperature': 8.45,
#   'description': 'light rain',
#   'feels_like': 6.34,
#   'rain': 1.32,
#   'wind_speed': 3.53}}

# %%
# or, create a Pandas DataFrame

weather_df = pd.DataFrame(
    {
        "date": weather_dt_txt,
        "temperature": weather_temp,
        "feels_like":  weather_feels_like,
        "rain_mm": weather_rain_mm,
        "weather_wind_speed": weather_wind_speed,
        "description": weather_description
    }
)

# %%
# describe
weather_df['temperature'].describe()
# Out:
# count    40.000000
# mean      8.110250
# std       1.656365
# min       2.740000
# 25%       7.365000
# 50%       8.465000
# 75%       9.222500
# max      10.840000
# Name: temperature, dtype: float64

# %% [markdown]
# # Assignments (2)

# %% [markdown]
# ## Assignment 1
#
# Add an additional column to the weather_df dataframe which indicates if it is freezing or not.

# %%
weather_df['freeze'] = np.where(weather_df['temperature'] > 0, "nee", "ja")
weather_df['freeze'].value_counts()
# Out:
# freeze
# nee    40
# Name: count, dtype: int64

# %% [markdown]
# ## Assignment 2
#
# Create a column that displays the temperatur in Fahrenheid

# %%
weather_df['temp_fahrenheit'] = weather_df['temperature'] * 1.8 + 31
weather_df[['temperature', 'temp_fahrenheit']]
# Out:
#     temperature  temp_fahrenheit
# 0          2.74           35.932
# 1          3.50           37.300
# 2          5.79           41.422
# 3          6.17           42.106
# 4          7.08           43.744
# 5          7.45           44.410
# 6          6.96           43.528
# 7          6.67           43.006
# 8          6.06           41.908
# 9          7.11           43.798
# 10         7.46           44.428
# 11        10.84           50.512
# 12         9.16           47.488
# 13         8.26           45.868
# 14         6.91           43.438
# 15         8.48           46.264
# 16         8.27           45.886
# 17         8.64           46.552
# 18         8.44           46.192
# 19         7.74           44.932
# 20         7.49           44.482
# 21         9.23           47.614
# 22         8.59           46.462
# 23         7.65           44.770
# 24         7.98           45.364
# 25         9.56           48.208
# 26         9.11           47.398
# 27         9.44           47.992
# 28        10.08           49.144
# 29         9.92           48.856
# 30         9.43           47.974
# 31         9.02           47.236
# 32         9.30           47.740
# 33         9.82           48.676
# 34         9.45           48.010
# 35         8.80           46.840
# 36         9.22           47.596
# 37         9.21           47.578
# 38         8.93           47.074
# 39         8.45           46.210

# %% [markdown]
# ## Assignment 3
#
# Filter the data frame which will only contain rows with a temperature higher than 7 degrees celcius

# %%
# with brackets
weather_df_subset = weather_df[weather_df['temperature'] > 7]
weather_df_subset.head()
# Out:
#                    date  temperature  feels_like  rain_mm  weather_wind_speed  \
# 4   2023-12-08 21:00:00         7.08        4.01     0.00                4.84
# 5   2023-12-09 00:00:00         7.45        4.35     0.00                5.13
# 9   2023-12-09 12:00:00         7.11        3.11     1.79                7.37
# 10  2023-12-09 15:00:00         7.46        3.29     3.56                8.29
# 11  2023-12-09 18:00:00        10.84       10.28     1.82                8.36
#
#         description freeze  temp_fahrenheit
# 4     broken clouds    nee           43.744
# 5   overcast clouds    nee           44.410
# 9        light rain    nee           43.798
# 10    moderate rain    nee           44.428
# 11       light rain    nee           50.512

# %%
# with .query
weather_df_subset = weather_df.query("temperature > 7")
weather_df_subset.head()
# Out:
#                    date  temperature  feels_like  rain_mm  weather_wind_speed  \
# 4   2023-12-08 21:00:00         7.08        4.01     0.00                4.84
# 5   2023-12-09 00:00:00         7.45        4.35     0.00                5.13
# 9   2023-12-09 12:00:00         7.11        3.11     1.79                7.37
# 10  2023-12-09 15:00:00         7.46        3.29     3.56                8.29
# 11  2023-12-09 18:00:00        10.84       10.28     1.82                8.36
#
#         description freeze  temp_fahrenheit
# 4     broken clouds    nee           43.744
# 5   overcast clouds    nee           44.410
# 9        light rain    nee           43.798
# 10    moderate rain    nee           44.428
# 11       light rain    nee           50.512

# %%
# specify the rains
rains = ['light rain', 'moderate rain', 'heavy rain']

# 
weather_df.query("description == @rains")
# Out:
#                    date  temperature  feels_like  rain_mm  weather_wind_speed  \
# 0   2023-12-08 09:00:00         2.74       -0.04     0.23                2.79
# 6   2023-12-09 03:00:00         6.96        3.68     0.13                5.24
# 9   2023-12-09 12:00:00         7.11        3.11     1.79                7.37
# 10  2023-12-09 15:00:00         7.46        3.29     3.56                8.29
# 11  2023-12-09 18:00:00        10.84       10.28     1.82                8.36
# 12  2023-12-09 21:00:00         9.16        5.27     0.16                9.23
# 13  2023-12-10 00:00:00         8.26        4.04     0.22                9.42
# 14  2023-12-10 03:00:00         6.91        2.09     1.18               10.10
# 15  2023-12-10 06:00:00         8.48        3.90     2.78               11.39
# 16  2023-12-10 09:00:00         8.27        3.86     0.22               10.25
# 19  2023-12-10 18:00:00         7.74        5.57     1.69                3.36
# 20  2023-12-10 21:00:00         7.49        5.06     0.88                3.73
# 26  2023-12-11 15:00:00         9.11        6.86     0.92                4.11
# 27  2023-12-11 18:00:00         9.44        6.62     0.51                5.75
# 28  2023-12-11 21:00:00        10.08        9.42     0.13                5.38
# 29  2023-12-12 00:00:00         9.92        7.57     0.15                4.78
# 30  2023-12-12 03:00:00         9.43        7.42     0.15                3.76
# 33  2023-12-12 12:00:00         9.82        8.56     0.13                2.57
# 34  2023-12-12 15:00:00         9.45        8.53     1.83                2.02
# 35  2023-12-12 18:00:00         8.80        7.35     0.29                2.57
# 36  2023-12-12 21:00:00         9.22        6.97     0.82                4.16
# 37  2023-12-13 00:00:00         9.21        6.85     2.02                4.40
# 38  2023-12-13 03:00:00         8.93        6.86     0.78                3.66
# 39  2023-12-13 06:00:00         8.45        6.34     1.32                3.53
#
#       description freeze  temp_fahrenheit
# 0      light rain    nee           35.932
# 6      light rain    nee           43.528
# 9      light rain    nee           43.798
# 10  moderate rain    nee           44.428
# 11     light rain    nee           50.512
# 12     light rain    nee           47.488
# 13     light rain    nee           45.868
# 14     light rain    nee           43.438
# 15     light rain    nee           46.264
# 16     light rain    nee           45.886
# 19     light rain    nee           44.932
# 20     light rain    nee           44.482
# 26     light rain    nee           47.398
# 27     light rain    nee           47.992
# 28     light rain    nee           49.144
# 29     light rain    nee           48.856
# 30     light rain    nee           47.974
# 33     light rain    nee           48.676
# 34     light rain    nee           48.010
# 35     light rain    nee           46.840
# 36     light rain    nee           47.596
# 37     light rain    nee           47.578
# 38     light rain    nee           47.074
# 39     light rain    nee           46.210

# %%
# specify the rains
rains = ['light rain', 'moderate rain', 'heavy rain']

# 
weather_df[weather_df['description'].isin(rains)]
# Out:
#                    date  temperature  feels_like  rain_mm  weather_wind_speed  \
# 0   2023-12-08 09:00:00         2.74       -0.04     0.23                2.79
# 6   2023-12-09 03:00:00         6.96        3.68     0.13                5.24
# 9   2023-12-09 12:00:00         7.11        3.11     1.79                7.37
# 10  2023-12-09 15:00:00         7.46        3.29     3.56                8.29
# 11  2023-12-09 18:00:00        10.84       10.28     1.82                8.36
# 12  2023-12-09 21:00:00         9.16        5.27     0.16                9.23
# 13  2023-12-10 00:00:00         8.26        4.04     0.22                9.42
# 14  2023-12-10 03:00:00         6.91        2.09     1.18               10.10
# 15  2023-12-10 06:00:00         8.48        3.90     2.78               11.39
# 16  2023-12-10 09:00:00         8.27        3.86     0.22               10.25
# 19  2023-12-10 18:00:00         7.74        5.57     1.69                3.36
# 20  2023-12-10 21:00:00         7.49        5.06     0.88                3.73
# 26  2023-12-11 15:00:00         9.11        6.86     0.92                4.11
# 27  2023-12-11 18:00:00         9.44        6.62     0.51                5.75
# 28  2023-12-11 21:00:00        10.08        9.42     0.13                5.38
# 29  2023-12-12 00:00:00         9.92        7.57     0.15                4.78
# 30  2023-12-12 03:00:00         9.43        7.42     0.15                3.76
# 33  2023-12-12 12:00:00         9.82        8.56     0.13                2.57
# 34  2023-12-12 15:00:00         9.45        8.53     1.83                2.02
# 35  2023-12-12 18:00:00         8.80        7.35     0.29                2.57
# 36  2023-12-12 21:00:00         9.22        6.97     0.82                4.16
# 37  2023-12-13 00:00:00         9.21        6.85     2.02                4.40
# 38  2023-12-13 03:00:00         8.93        6.86     0.78                3.66
# 39  2023-12-13 06:00:00         8.45        6.34     1.32                3.53
#
#       description freeze  temp_fahrenheit
# 0      light rain    nee           35.932
# 6      light rain    nee           43.528
# 9      light rain    nee           43.798
# 10  moderate rain    nee           44.428
# 11     light rain    nee           50.512
# 12     light rain    nee           47.488
# 13     light rain    nee           45.868
# 14     light rain    nee           43.438
# 15     light rain    nee           46.264
# 16     light rain    nee           45.886
# 19     light rain    nee           44.932
# 20     light rain    nee           44.482
# 26     light rain    nee           47.398
# 27     light rain    nee           47.992
# 28     light rain    nee           49.144
# 29     light rain    nee           48.856
# 30     light rain    nee           47.974
# 33     light rain    nee           48.676
# 34     light rain    nee           48.010
# 35     light rain    nee           46.840
# 36     light rain    nee           47.596
# 37     light rain    nee           47.578
# 38     light rain    nee           47.074
# 39     light rain    nee           46.210

# %%
# should contain the term 'cloud'
term_cloud = 'cloud'

# 
weather_df.query("description.str.contains(@term_cloud) & temperature < 7", engine="python")
# Out:
#                   date  temperature  feels_like  rain_mm  weather_wind_speed  \
# 1  2023-12-08 12:00:00         3.50        1.05      0.0                2.58
# 2  2023-12-08 15:00:00         5.79        3.45      0.0                3.00
# 3  2023-12-08 18:00:00         6.17        3.60      0.0                3.48
# 7  2023-12-09 06:00:00         6.67        3.18      0.0                5.57
# 8  2023-12-09 09:00:00         6.06        2.19      0.0                6.13
#
#        description freeze  temp_fahrenheit
# 1    broken clouds    nee           37.300
# 2  overcast clouds    nee           41.422
# 3    broken clouds    nee           42.106
# 7  overcast clouds    nee           43.006
# 8  overcast clouds    nee           41.908

# %%
# str. for the string accessors
weather_df['description'].str.split().str[0]
# Out:
# 0        light
# 1       broken
# 2     overcast
# 3       broken
# 4       broken
# 5     overcast
# 6        light
# 7     overcast
# 8     overcast
# 9        light
# 10    moderate
# 11       light
# 12       light
# 13       light
# 14       light
# 15       light
# 16       light
# 17    overcast
# 18    overcast
# 19       light
# 20       light
# 21    overcast
# 22    overcast
# 23    overcast
# 24    overcast
# 25    overcast
# 26       light
# 27       light
# 28       light
# 29       light
# 30       light
# 31    overcast
# 32    overcast
# 33       light
# 34       light
# 35       light
# 36       light
# 37       light
# 38       light
# 39       light
# Name: description, dtype: object

# %%
# str. for the string accessors
weather_df['description'].str.replace("i", "y")
# Out:
# 0          lyght rayn
# 1       broken clouds
# 2     overcast clouds
# 3       broken clouds
# 4       broken clouds
# 5     overcast clouds
# 6          lyght rayn
# 7     overcast clouds
# 8     overcast clouds
# 9          lyght rayn
# 10      moderate rayn
# 11         lyght rayn
# 12         lyght rayn
# 13         lyght rayn
# 14         lyght rayn
# 15         lyght rayn
# 16         lyght rayn
# 17    overcast clouds
# 18    overcast clouds
# 19         lyght rayn
# 20         lyght rayn
# 21    overcast clouds
# 22    overcast clouds
# 23    overcast clouds
# 24    overcast clouds
# 25    overcast clouds
# 26         lyght rayn
# 27         lyght rayn
# 28         lyght rayn
# 29         lyght rayn
# 30         lyght rayn
# 31    overcast clouds
# 32    overcast clouds
# 33         lyght rayn
# 34         lyght rayn
# 35         lyght rayn
# 36         lyght rayn
# 37         lyght rayn
# 38         lyght rayn
# 39         lyght rayn
# Name: description, dtype: object

# %%
# create a new (higher) category for the description
weather_df['description_overall'] = weather_df['description'].str.split(" ").str[-1]
weather_df['description_overall'].value_counts()
# Out:
# description_overall
# rain      24
# clouds    16
# Name: count, dtype: int64
