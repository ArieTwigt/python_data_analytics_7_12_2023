# %%
import pandas as pd

# %%
# import the data
data = pd.read_csv("data/german_data_clean.csv")

# %%
data
# Out:
#          checking_account  duration_months  \
# 0           ... <  0 euro                6
# 1    0 <= ... <  102 euro               48
# 2     No checking account               12
# 3           ... <  0 euro               42
# 4           ... <  0 euro               24
# ..                    ...              ...
# 995   No checking account               12
# 996         ... <  0 euro               30
# 997   No checking account               12
# 998         ... <  0 euro               45
# 999  0 <= ... <  102 euro               45
#
#                                         credit_history              purpose  \
# 0    critical account/other credits existing (not a...     radio/television
# 1             existing credits paid back duly till now     radio/television
# 2    critical account/other credits existing (not a...            education
# 3             existing credits paid back duly till now  furniture/equipment
# ...

# %%
data.loc[[13, 100,569], "duration_months"]
# Out:
# 13     24
# 100    24
# 569    48
# Name: duration_months, dtype: int64

# %%
# 
data.head()
# Out:
#        checking_account  duration_months  \
# 0         ... <  0 euro                6
# 1  0 <= ... <  102 euro               48
# 2   No checking account               12
# 3         ... <  0 euro               42
# 4         ... <  0 euro               24
#
#                                       credit_history              purpose  \
# 0  critical account/other credits existing (not a...     radio/television
# 1           existing credits paid back duly till now     radio/television
# 2  critical account/other credits existing (not a...            education
# 3           existing credits paid back duly till now  furniture/equipment
# 4                    delay in paying off in the past            car (new)
#
#    credit_amount                      savings present_employment_since  \
# 0           1169  unknown/ no savings account            .. >= 7 years
# 1           5951               ... <  51 euro      1  <= ... < 4 years
# ...

# %%
data_sorted = data.sort_values(by="duration_months")
data_sorted.head()
# Out:
#         checking_account  duration_months  \
# 314          >= 102 euro                4
# 734  No checking account                4
# 527  No checking account                4
# 943  No checking account                4
# 837  No checking account                4
#
#                                         credit_history              purpose  \
# 314           existing credits paid back duly till now            car (new)
# 734  critical account/other credits existing (not a...            car (new)
# 527  critical account/other credits existing (not a...     radio/television
# 943  critical account/other credits existing (not a...            car (new)
# 837           existing credits paid back duly till now  furniture/equipment
#
#      credit_amount                      savings present_employment_since  \
# 314           1494  unknown/ no savings account             ... < 1 year
# 734           3380               ... <  51 euro      4  <= ... < 7 years
# ...

# %%
data.loc[0]
# Out:
# checking_account                                                 ... <  0 euro
# duration_months                                                              6
# credit_history               critical account/other credits existing (not a...
# purpose                                                       radio/television
# credit_amount                                                             1169
# savings                                            unknown/ no savings account
# present_employment_since                                         .. >= 7 years
# installment_rate                                                             4
# personal_status_sex                                            male   : single
# other_deptors                                                             none
# present_residence                                                            4
# property                                                           real estate
# ...

# %%
data_sorted.loc[0]
# Out:
# checking_account                                                 ... <  0 euro
# duration_months                                                              6
# credit_history               critical account/other credits existing (not a...
# purpose                                                       radio/television
# credit_amount                                                             1169
# savings                                            unknown/ no savings account
# present_employment_since                                         .. >= 7 years
# installment_rate                                                             4
# personal_status_sex                                            male   : single
# other_deptors                                                             none
# present_residence                                                            4
# property                                                           real estate
# ...

# %%
# lamba

data.head()
# Out:
#        checking_account  duration_months  \
# 0         ... <  0 euro                6
# 1  0 <= ... <  102 euro               48
# 2   No checking account               12
# 3         ... <  0 euro               42
# 4         ... <  0 euro               24
#
#                                       credit_history              purpose  \
# 0  critical account/other credits existing (not a...     radio/television
# 1           existing credits paid back duly till now     radio/television
# 2  critical account/other credits existing (not a...            education
# 3           existing credits paid back duly till now  furniture/equipment
# 4                    delay in paying off in the past            car (new)
#
#    credit_amount                      savings present_employment_since  \
# 0           1169  unknown/ no savings account            .. >= 7 years
# 1           5951               ... <  51 euro      1  <= ... < 4 years
# ...

# %%
loan_value = lambda amount, installment, months: amount * (1 + (installment / 100)) ** (months /12)

# %%
loan_value(1000, 2, 24)
# Out:
# 1040.4

# %%
data.apply(lambda row: loan_value(row['credit_amount'], row['installment_rate'], row['duration_months']), axis=1)
# Out:
# 0      1192.150762
# 1      6441.553784
# 2      2137.920000
# 3      8447.671779
# 4      5166.583000
#           ...
# 995    1788.080000
# 996    4254.347759
# 997     836.160000
# 998    2137.329071
# 999    5112.409209
# Length: 1000, dtype: float64

# %%
def load_value(amount, installment, months):
    pass

# %%
data['loan_type'].value_counts()
# Out:
# loan_type
# normal    1000
# Name: count, dtype: int64
